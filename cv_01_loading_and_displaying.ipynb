# %% [markdown]
# # Loading and showing images

# %% [markdown]
# ## Include needed packages

# %%
import cv2 as cv
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

# This is needed to display the images.
# %matplotlib inline

# %% [markdown]
# ## Load image

# %%
# The path to (relative to where jupyter is running) the image to load
imageName = "test_images/lena.jpg"

# Load the source image
image = cv.imread(imageName)

# We can comvert the image directly to gray scale if we want.
# We do that??? Well, in many cases the algorithm we want to run is not using the color information.
# cv2.IMREAD_COLOR (1)     : Loads a color image. Any transparency of image will be neglected. It is the default flag.
# cv2.IMREAD_GRAYSCALE (0) : Loads image in grayscale mode
# cv2.IMREAD_UNCHANGED (-1): Loads image as such including alpha channel
imageG = cv.imread(imageName, cv.IMREAD_GRAYSCALE)

print("We remind ourself about the fact that images are merely matrices with numbers")
print(imageG)
# Out:
# We remind ourself about the fact that images are merely matrices with numbers
# [[161 161 162 ..., 166 170 145]
#  [161 161 161 ..., 177 177 142]
#  [161 161 161 ..., 157 149 114]
#  ...,
#  [ 48  53  53 ...,  84  92  95]
#  [ 47  51  51 ...,  93  98  98]
#  [ 44  48  50 ..., 101 107 108]]

# %% [markdown]
# ## Show the image
# We use the matplotlib to display the images so that we can do it inline in the notebook

# %%
# Show the gray image
plt.imshow(imageG, cmap = 'gray')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# Show the color image. Note that OpenCV represents the image data as BGR instead of RGB so we need to convert first
plt.imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
